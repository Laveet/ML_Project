# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url="data\stud.csv"
df=pd.read_csv(url)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\lavee\AppData\Local\Temp\ipykernel_26308\3678135310.py:1: SyntaxWarning: invalid escape sequence '\s'
#   url="data\stud.csv"
