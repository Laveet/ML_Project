# %%
import pandas as pd

# %%
url=r"C:\Users\lavee\Desktop\ML_Project\Notebook\data\stud.csv"
df=pd.read_csv(r"C:\Users\lavee\Desktop\ML_Project\Notebook\data\stud.csv")

# %%
models={
                "Random Forest": 1,
                "Decision Tree": 2,
                "Gradient Boosting": 3,
                "Linear Regression": 4,
                
            }
report= {}
for i in range(len(list(models))):
    model=list(models.values())[i]
    score=model*2
    # report[list(models.keys())[i]]=score
    print()

# %%
best=max(report.values())

list(report.keys())[list(report.values()).index(best)]
# Out:
# 'Linear Regression'
